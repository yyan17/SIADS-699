# %% [markdown]
# # Importing libraries

# %%
import torch
import torch.nn as nn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from captum.attr import IntegratedGradients
import altair as alt
from sklearn.metrics import mean_absolute_percentage_error

# %%
seed = 0
torch.manual_seed(seed)

# %% [markdown]
# # Importing data

# %%
DF = pd.read_csv('../datasets/processed_data/combined_features/TV18BRDCST.BO.csv.gz')

# %%
sentiments = ['agg_polarity', 'agg_compound', 'topic_polarity', 'topic_compound', 'ticker_polarity', 'ticker_compound']

# %%
DF.head()
# Out:
#          date        open       close   adj close  volume        high  \
# 0  2008-06-03  108.000000  107.349998  107.349998   10174  110.500000
# 1  2008-06-04  108.800003  101.000000  101.000000   10123  108.800003
# 2  2008-06-05  102.000000  100.800003  100.800003   17818  102.349998
# 3  2008-06-06  104.000000   98.599998   98.599998    9493  104.699997
# 4  2008-06-09   95.000000   91.050003   91.050003   11966   95.000000
#
#           low    volume_adi  volume_obv  volume_cmf  ...  \
# 0  105.000000  -8646.638187       -2320   -0.326802  ...
# 1   99.050003 -14720.444524      -12443   -0.326802  ...
# 2   96.199997  -5883.846665      -30261   -0.326802  ...
# 3   97.000000 -11431.706006      -39754   -0.326802  ...
# 4   88.000000 -12970.181287      -51720   -0.326802  ...
#
#    treasury_yeild_10_years_percent_change  usdx-index_percent_change  \
# 0                               -0.018383                   0.004251
# 1                               -0.018383                   0.004251
# 2                                0.010775                   0.002458
# 3                                0.021574                  -0.005176
# 4                                0.021574                  -0.005176
#
#    ^nsei_percent_change  ^bsesn_percent_change  ^gspc_percent_change  \
# 0             -0.026796              -0.021467             -0.010504
# 1             -0.005000              -0.006264             -0.005788
# 2             -0.027630              -0.028051             -0.000327
# 3              0.019921               0.016431              0.019496
# 4             -0.010509              -0.012527             -0.030889
#
#    hsi_percent_change  sha_percent_change  ^sti_percent_change  \
# 0            0.015385           -0.011495                  0.0
# 1            0.015385           -0.011495                  0.0
# 2            0.015385           -0.011495                  0.0
# 3            0.015385           -0.011495                  0.0
# 4            0.015385           -0.011495                  0.0
#
#    yesterday_close  ln_target
# 0       110.349998   0.001358
# 1       107.349998   0.013417
# 2       101.000000   0.013278
# 3       100.800003   0.037961
# 4        98.599998  -0.037194
#
# [5 rows x 635 columns]

# %%
# Plot the stock
plt.plot(DF['open'].values)
plt.show()

# %%
# checking_number of features
len(list(DF.columns))
# Out:
# 635

# %%
DF.shape
# Out:
# (4020, 635)

# %%
# Instead of predicting the stock price itself, 
# we will predict log value of "High"/"Yesterday Close" as we need stationary time-series

# %%
def create_custom_target(df: pd.DataFrame) -> pd.DataFrame:
    """
    This function creates the custom target price, which is computed as ln(high/yesterday_close)
    """    
    # make a copy of the dataframe so as not to change the original dataframe
    data_df = df.copy()
    
    # create yesterday_close feature as
    data_df['yesterday_close'] = data_df['close'].shift(1)
    
    # create custom target price to predict, computing  ln(high/yesterday_close)
    data_df['ln_target'] = np.log(data_df['high'] / data_df['yesterday_close'])
    
    # as yesterday close would not be available for first day, 
    # we would not have custom target price for that day, which needs to be excluded 
    return(data_df.iloc[1:, ])

# %%
DF = create_custom_target(DF)

# %%
DF.head(5)
# Out:
#          date        open       close   adj close  volume        high  \
# 1  2008-06-04  108.800003  101.000000  101.000000   10123  108.800003
# 2  2008-06-05  102.000000  100.800003  100.800003   17818  102.349998
# 3  2008-06-06  104.000000   98.599998   98.599998    9493  104.699997
# 4  2008-06-09   95.000000   91.050003   91.050003   11966   95.000000
# 5  2008-06-10   90.000000   89.300003   89.300003   10482   92.599998
#
#          low    volume_adi  volume_obv  volume_cmf  ...  \
# 1  99.050003 -14720.444524      -12443   -0.326802  ...
# 2  96.199997  -5883.846665      -30261   -0.326802  ...
# 3  97.000000 -11431.706006      -39754   -0.326802  ...
# 4  88.000000 -12970.181287      -51720   -0.326802  ...
# 5  86.000000 -12970.169170      -62202   -0.326802  ...
#
#    treasury_yeild_10_years_percent_change  usdx-index_percent_change  \
# 1                               -0.018383                   0.004251
# 2                                0.010775                   0.002458
# 3                                0.021574                  -0.005176
# 4                                0.021574                  -0.005176
# 5                                0.021574                  -0.005176
#
#    ^nsei_percent_change  ^bsesn_percent_change  ^gspc_percent_change  \
# 1             -0.005000              -0.006264             -0.005788
# 2             -0.027630              -0.028051             -0.000327
# 3              0.019921               0.016431              0.019496
# 4             -0.010509              -0.012527             -0.030889
# 5             -0.027410              -0.032499              0.000794
#
#    hsi_percent_change  sha_percent_change  ^sti_percent_change  \
# 1            0.015385           -0.011495                  0.0
# 2            0.015385           -0.011495                  0.0
# 3            0.015385           -0.011495                  0.0
# 4            0.015385           -0.011495                  0.0
# 5           -0.015228           -0.011495                  0.0
#
#    yesterday_close  ln_target
# 1       107.349998   0.013417
# 2       101.000000   0.013278
# 3       100.800003   0.037961
# 4        98.599998  -0.037194
# 5        91.050003   0.016880
#
# [5 rows x 635 columns]

# %% [markdown]
# # LSTM for all features

# %%
# First step we run LSTM model for all features (but only for teh last ~750 days), then we will use that model to 
# identify which features are the most important using Captum library.

# %%
df = DF.iloc[3286:,:]

# %%
input_data = df.drop(['ln_target', 'date'], axis=1).values
targets = df['ln_target'].values

# %%
targets.shape
# Out:
# (733,)

# %%
input_data.shape
# Out:
# (733, 633)

# %%
labels = df.drop(['ln_target', 'date'], axis=1).columns
labels
# Out:
# Index(['open', 'close', 'adj close', 'volume', 'high', 'low', 'volume_adi',
#        'volume_obv', 'volume_cmf', 'volume_fi',
#        ...
#        'cl=f_percent_change', 'treasury_yeild_10_years_percent_change',
#        'usdx-index_percent_change', '^nsei_percent_change',
#        '^bsesn_percent_change', '^gspc_percent_change', 'hsi_percent_change',
#        'sha_percent_change', '^sti_percent_change', 'yesterday_close'],
#       dtype='object', length=633)

# %%
len(targets)
# Out:
# 733

# %%
# number of input features
input_data.shape[1]
# Out:
# 633

# %%
# Preparing data the neural network
T = 65 # the number of days in one quarter to look at to make a prediction for the next day
D = input_data.shape[1] # number of features
N = len(input_data) - T # Number of samples with Time window length (e.g. if T=10 and you have 11 data points then you'd only have 1 sample and you will predict the 11th one)

# %%
input_data
# Out:
# array([[ 3.15000000e+01,  3.03500004e+01,  3.03500004e+01, ...,
#         -2.00803213e-03,  1.79736777e-03,  3.12000008e+01],
#        [ 3.06000004e+01,  2.92999992e+01,  2.92999992e+01, ...,
#          0.00000000e+00, -2.69455714e-03,  3.03500004e+01],
#        [ 2.98500004e+01,  2.91499996e+01,  2.91499996e+01, ...,
#          7.82778865e-03,  2.17614722e-03,  2.92999992e+01],
#        ...,
#        [ 3.48899994e+01,  3.42200012e+01,  3.42200012e+01, ...,
#          0.00000000e+00, -4.14649077e-04,  3.43600006e+01],
#        [ 3.44700012e+01,  3.52700005e+01,  3.52700005e+01, ...,
#          0.00000000e+00, -2.78507454e-04,  3.42200012e+01],
#        [ 3.50099983e+01,  3.50200005e+01,  3.50200005e+01, ...,
#          0.00000000e+00, -3.25958932e-03,  3.52700005e+01]])

# %%
# split and normalize the inputs
Ntrain = len(input_data) * 4 // 5
scaler = StandardScaler()
scaler.fit(input_data[:Ntrain + T - 1])
input_data[:Ntrain + T - 1] = scaler.transform(input_data[:Ntrain + T - 1])
input_data[Ntrain + T - 1:] = scaler.transform(input_data[Ntrain + T - 1:])

# %%
# We keep checking the length and shapes of input for PyTorch model

# %%
Ntrain
# Out:
# 586

# %%
len(input_data)
# Out:
# 733

# %%
Ntrain + T - 1
# Out:
# 650

# %%
# Setup X_train and Y_train
X_train = np.zeros((Ntrain, T, D))
Y_train = np.zeros((Ntrain, 1))
for t in range(Ntrain):
    X_train[t, :, :] = input_data[t:t+T]
    Y_train[t] = targets[t+T]

# %%
# Setup X_test and Y_test
X_test = np.zeros((N - Ntrain, T, D))
Y_test = np.zeros((N - Ntrain, 1))
for u in range(N - Ntrain):
    t = u + Ntrain
    X_test[u, :, :] = input_data[t:t+T]
    Y_test[u] = targets[t+T]

# %%
### LSTM model
class RNN(nn.Module):
  def __init__(self, n_inputs, n_hidden, n_rnnlayers, n_outputs):
    super(RNN, self).__init__()
    self.D = n_inputs
    self.M = n_hidden
    self.K = n_outputs
    self.L = n_rnnlayers

    self.rnn = nn.LSTM(
        input_size=self.D,
        hidden_size=self.M,
        num_layers=self.L,
        dropout = 0.5, # to avoid overfitting
        batch_first=True)
    self.fc = nn.Linear(self.M, self.K)
  
  def forward(self, X):
    # initial hidden and cell states
    h0 = torch.zeros(self.L, X.size(0), self.M).to(device)
    c0 = torch.zeros(self.L, X.size(0), self.M).to(device)

    # get LSTM output
    out, _ = self.rnn(X, (h0, c0))

    # we only want h(T) at the final time step (-1)
    out = self.fc(out[:, -1, :])
    return out

# %%
# make the LSTM with 500 hidden features and 1 layers
model = RNN(input_data.shape[1], 500, 1, 1)
device = torch.device('cpu')
print(device)
model.to(device)
# Out:
# cpu
# /Users/shamil/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/rnn.py:62: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
# RNN(
#   (rnn): LSTM(633, 500, batch_first=True, dropout=0.5)
#   (fc): Linear(in_features=500, out_features=1, bias=True)
# )

# %%
# Loss and optimizer: Depends on the task different Loss function can be used 
# criterion = nn.BCEWithLogitsLoss() # if classification task
criterion = nn.L1Loss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.1)

# %%
# Make inputs and targets
X_train = torch.from_numpy(X_train.astype(np.float32))
y_train = torch.from_numpy(Y_train.astype(np.float32))
X_test = torch.from_numpy(X_test.astype(np.float32))
y_test = torch.from_numpy(Y_test.astype(np.float32))

# %%
# move data to GPU
X_train, y_train = X_train.to(device), y_train.to(device)
X_test, y_test = X_test.to(device), y_test.to(device)

# %%
def checkpoint(model, filename):
    torch.save(model.state_dict(), filename)

# %%
# Training
def full_gd(model,
           criterion,
           optimizer,
           X_train,
           y_train,
           X_test,
           y_test,
           epochs = 200):
    # stuff to store
    train_losses = np.zeros(epochs)
    test_losses = np.zeros(epochs)
    
    for it in range(epochs):
        #zero the parameter gradients
        optimizer.zero_grad()
        
        # Forward pass
        outputs = model(X_train)
        loss = criterion(outputs, y_train)
        
        #Backward and optimize
        loss.backward()
        optimizer.step()
        
        #Save losses
        train_losses[it] = loss.item()
        
        #Test loss
        test_outputs = model(X_test)
        test_loss = criterion(test_outputs, y_test)
        test_losses[it] = test_loss.item()
        
        if (it+1)%5 == 0:
            print(f'Epoch {it+1}/{epochs}, Train Loss: {loss.item():.4f}, test Loss: {test_loss.item():.4f}')
            #checkpoint(model, f"LSTM/Epoch_TV18BRDCST_633-{it+1}.pth") # if you want to save each epoch model for further early stop
    return train_losses, test_losses

# %%
train_losses, test_losses = full_gd(model,
                                    criterion,
                                    optimizer,
                                    X_train,
                                    y_train,
                                    X_test,
                                    y_test,
                                    epochs=300)
# Out:
# Epoch 5/300, Train Loss: 2.3076, test Loss: 5.7218
# Epoch 10/300, Train Loss: 3.2164, test Loss: 1.3357
# Epoch 15/300, Train Loss: 2.1049, test Loss: 0.8159
# Epoch 20/300, Train Loss: 1.5836, test Loss: 1.4377
# Epoch 25/300, Train Loss: 1.0275, test Loss: 1.0105
# Epoch 30/300, Train Loss: 0.8184, test Loss: 1.4470
# Epoch 35/300, Train Loss: 1.5956, test Loss: 1.9696
# Epoch 40/300, Train Loss: 1.4706, test Loss: 2.3549
# Epoch 45/300, Train Loss: 0.7693, test Loss: 1.5702
# Epoch 50/300, Train Loss: 0.9420, test Loss: 0.3646
# Epoch 55/300, Train Loss: 0.6747, test Loss: 0.8690
# Epoch 60/300, Train Loss: 0.5735, test Loss: 0.7412
# Epoch 65/300, Train Loss: 1.2266, test Loss: 1.5917
# Epoch 70/300, Train Loss: 0.8716, test Loss: 2.0275
# Epoch 75/300, Train Loss: 0.7462, test Loss: 1.1555
# Epoch 80/300, Train Loss: 1.6477, test Loss: 0.4363
# Epoch 85/300, Train Loss: 2.0625, test Loss: 0.6997
# Epoch 90/300, Train Loss: 0.9994, test Loss: 0.5259
# Epoch 95/300, Train Loss: 1.0859, test Loss: 0.2792
# Epoch 100/300, Train Loss: 0.4376, test Loss: 0.4880
# Epoch 105/300, Train Loss: 1.0487, test Loss: 0.7072
# Epoch 110/300, Train Loss: 0.6500, test Loss: 0.4860
# Epoch 115/300, Train Loss: 0.5848, test Loss: 0.4903
# Epoch 120/300, Train Loss: 0.7839, test Loss: 0.8643
# Epoch 125/300, Train Loss: 0.5573, test Loss: 0.2322
# Epoch 130/300, Train Loss: 0.6407, test Loss: 0.3391
# Epoch 135/300, Train Loss: 0.9289, test Loss: 0.3774
# Epoch 140/300, Train Loss: 0.9782, test Loss: 0.2437
# Epoch 145/300, Train Loss: 0.4137, test Loss: 0.4362
# Epoch 150/300, Train Loss: 0.7253, test Loss: 0.1997
# Epoch 155/300, Train Loss: 0.6018, test Loss: 1.1104
# Epoch 160/300, Train Loss: 0.5948, test Loss: 0.2993
# Epoch 165/300, Train Loss: 0.9561, test Loss: 0.4993
# Epoch 170/300, Train Loss: 1.1502, test Loss: 0.8061
# Epoch 175/300, Train Loss: 0.4744, test Loss: 0.8584
# Epoch 180/300, Train Loss: 1.1493, test Loss: 1.2217
# Epoch 185/300, Train Loss: 0.5522, test Loss: 0.2849
# Epoch 190/300, Train Loss: 0.4330, test Loss: 0.8719
# Epoch 195/300, Train Loss: 0.9011, test Loss: 0.4094
# Epoch 200/300, Train Loss: 0.7610, test Loss: 0.1946
# Epoch 205/300, Train Loss: 0.5414, test Loss: 0.3421
# Epoch 210/300, Train Loss: 0.7879, test Loss: 0.4889
# Epoch 215/300, Train Loss: 0.5426, test Loss: 0.3566
# Epoch 220/300, Train Loss: 0.5346, test Loss: 0.1965
# Epoch 225/300, Train Loss: 1.1210, test Loss: 0.4741
# Epoch 230/300, Train Loss: 0.7664, test Loss: 0.4204
# Epoch 235/300, Train Loss: 0.3726, test Loss: 0.1758
# Epoch 240/300, Train Loss: 0.8011, test Loss: 0.5666
# Epoch 245/300, Train Loss: 1.0168, test Loss: 0.8815
# Epoch 250/300, Train Loss: 0.6026, test Loss: 0.4831
# Epoch 255/300, Train Loss: 1.2340, test Loss: 1.2534
# Epoch 260/300, Train Loss: 0.8271, test Loss: 0.8829
# Epoch 265/300, Train Loss: 1.4167, test Loss: 1.4953
# Epoch 270/300, Train Loss: 1.3596, test Loss: 2.3795
# Epoch 275/300, Train Loss: 0.6099, test Loss: 0.9830
# Epoch 280/300, Train Loss: 0.7526, test Loss: 1.1140
# Epoch 285/300, Train Loss: 1.7190, test Loss: 1.9223
# Epoch 290/300, Train Loss: 0.9298, test Loss: 1.1174
# Epoch 295/300, Train Loss: 1.2010, test Loss: 1.3921
# Epoch 300/300, Train Loss: 0.8127, test Loss: 0.8442

# %%
# Plot the train loss and test loss per iteration
plt.plot(train_losses, label='train loss')
plt.plot(test_losses, label='test loss')
plt.legend()
plt.show()

# %%
# Model results are not stable, but overall loss values goes down. 15 episodes are good enough to train the model.
# We can save weights for each episode and then retrieve the desired one.

# %%
# retrieving 200th iteration
model = RNN(input_data.shape[1], 500, 1, 1)
model.load_state_dict(torch.load('LSTM/Epoch_TV18BRDCST_633_all-200.pth'))
model.eval()
# Out:
# /Users/shamil/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/rnn.py:62: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
# RNN(
#   (rnn): LSTM(633, 500, batch_first=True, dropout=0.5)
#   (fc): Linear(in_features=500, out_features=1, bias=True)
# )

# %%
X_on_device = X_test.to(device)

# %%
X_on_device.shape
# Out:
# torch.Size([82, 65, 633])

# %%
# One-step forecast 
test_target = np.exp(Y_test)
test_predictions = []
# index of first test input
i = 0
X_on_device = X_test.to(device)
while len(test_predictions) < len(test_target):
    input_ = X_on_device[i].reshape(-1, T, input_data.shape[1])
    p = model(input_)[0,0].item() 
    i += 1
    test_predictions.append(np.exp(p))

# %%
plt.plot(test_target, label = 'forecast target')
plt.plot(test_predictions, label = 'forecast prediction')
plt.legend()

# %%
# Low performance is most likely related to the absence of signal?
# Lets do feature importance exercise with captum tool and run LSTM with top 50 selected features with sentiment and without

# %% [markdown]
# # Feature selection with Captum

# %% [markdown]
# As we have more than 600 features, first we apply Captum library which will help us which features are most important. For that we need to provide baseline (in this case we use zeros). Then the model will replace some features with baseline values and see the difference on outcome. There are several options in captum library, like global features, local features etc. We apply global ones to see which features are overall are the most critical for the model.

# %%
X_train.size()
# Out:
# torch.Size([586, 65, 633])

# %%
baseline = torch.zeros(Ntrain, T, input_data.shape[1])

# %%
ig = IntegratedGradients(model)
attributions, delta = ig.attribute(X_train, baseline, method='gausslegendre', return_convergence_delta=True)
print('IG Attributions:', attributions)
print('Convergence Delta:', delta)
# Out:
# IG Attributions: tensor([[[ 7.8200e+01,  3.7762e+01,  3.5807e+01,  ..., -4.6604e+01,
#           -3.3646e+01,  9.5952e+01],
#          [ 5.5362e+01,  1.0758e+02,  9.8681e+01,  ...,  1.9874e-01,
#            5.2612e+01,  1.0048e+02],
#          [ 1.5280e+02,  1.6575e+02,  1.6627e+02,  ...,  5.7411e+01,
#            2.8512e+00,  1.8752e+02],
#          ...,
#          [ 5.6479e-03,  5.5167e-03,  5.5449e-03,  ..., -1.0713e-03,
#           -7.5194e-03,  4.1805e-03],
#          [-8.1059e-03, -9.4016e-03, -9.3138e-03,  ...,  1.5994e-03,
#           -5.9865e-03, -8.4936e-03],
#          [ 2.5437e-03, -8.7634e-04, -8.8042e-04,  ..., -3.4236e-03,
#            1.5738e-02, -2.1757e-03]],
#
#         [[-1.9509e+02, -5.2300e+01, -5.8697e+01,  ..., -7.9617e-01,
#           -1.6331e+02, -1.1601e+02],
#          [ 1.1114e+02,  1.5167e+02,  1.8035e+02,  ...,  3.0933e+01,
#           -5.6684e+01,  2.2037e+02],
#          [ 1.8112e+02,  3.1494e+02,  3.2698e+02,  ..., -8.8578e+02,
#            4.4233e+01,  3.1435e+02],
#          ...,
#          [-1.1369e-02, -1.0659e-02, -1.0540e-02,  ..., -5.8353e-04,
#           -1.2278e-02, -1.0750e-02],
#          [ 7.5463e-03,  5.4166e-03,  5.6819e-03,  ..., -1.8025e-04,
#            6.2289e-04,  5.4622e-03],
#          [ 2.3692e-03, -2.5744e-03, -3.1892e-03,  ..., -1.6246e-03,
#            2.0643e-03, -3.4627e-03]],
#
#         [[ 2.9936e+01, -4.0530e+01, -3.8292e+01,  ...,  1.4110e+02,
#           -2.7428e+01,  3.2782e+01],
#          [-1.0162e+02, -1.2882e+02, -1.3435e+02,  ..., -1.4582e+00,
#           -6.7723e+00, -1.5261e+02],
#          [-6.6571e+01, -7.8726e+01, -7.6549e+01,  ...,  2.6424e+02,
#           -9.6924e+01, -6.7432e+01],
#          ...,
#          [ 6.9891e-03,  5.2588e-03,  4.9220e-03,  ...,  2.5789e-05,
#           -1.8722e-04,  4.7987e-03],
#          [ 3.3229e-03,  1.4347e-03,  4.9131e-04,  ...,  1.9356e-03,
#            1.4748e-02,  2.2597e-03],
#          [-3.3327e-03, -1.9670e-03, -2.2682e-03,  ..., -1.9693e-02,
#           -1.6437e-03, -3.6584e-03]],
#
#         ...,
#
#         [[-2.1916e-04,  1.1202e-03,  1.1529e-03,  ..., -1.5497e-05,
#            2.5031e-03,  3.7448e-04],
#          [-5.4504e-05, -4.0499e-05, -4.4778e-05,  ..., -2.1882e-07,
#           -2.9516e-06, -3.1816e-05],
#          [-8.0582e-05, -5.7774e-05, -5.5090e-05,  ..., -7.8584e-07,
#           -7.5080e-05, -4.9579e-05],
#          ...,
#          [-1.7164e-04, -5.4303e-04, -5.4439e-04,  ..., -1.6644e-06,
#           -2.5723e-05, -4.9541e-04],
#          [-1.0053e-04,  1.9903e-04,  2.3233e-04,  ..., -2.0576e-06,
#            2.3747e-05,  1.9934e-04],
#          [-2.9804e-03, -3.4029e-03, -3.3043e-03,  ..., -1.7884e-05,
#            1.7068e-03, -3.2328e-03]],
#
#         [[-1.5312e-04,  1.3258e-03,  1.3704e-03,  ..., -1.4417e-05,
#           -1.8527e-04,  5.6998e-04],
#          [-6.2692e-05, -5.8254e-05, -6.4999e-05,  ..., -3.3012e-07,
#           -2.8314e-05, -5.1395e-05],
#          [-4.2681e-05, -4.2751e-05, -4.9684e-05,  ..., -7.2200e-07,
#           -2.1742e-05, -6.1715e-05],
#          ...,
#          [-9.5020e-05, -3.6169e-04, -3.6716e-04,  ..., -6.1640e-07,
#           -3.5200e-06, -3.4914e-04],
#          [ 1.8894e-04,  4.8783e-04,  5.1600e-04,  ..., -1.3408e-06,
#            1.8412e-03,  4.3728e-04],
#          [-2.7977e-03, -4.0578e-03, -3.9827e-03,  ..., -1.4971e-05,
#            5.0480e-04, -3.6666e-03]],
#
#         [[-1.9974e-04,  6.5701e-04,  6.0180e-04,  ..., -1.2908e-05,
#           -1.0586e-03,  3.6022e-05],
#          [ 1.3920e-03, -2.0529e-04, -4.4311e-04,  ...,  3.8456e-06,
#           -2.2856e-03, -1.2817e-03],
#          [ 2.3096e-04, -8.0840e-04, -1.0589e-03,  ..., -3.7793e-06,
#           -1.0269e-03, -1.4389e-03],
#          ...,
#          [-1.8305e-04, -3.7478e-04, -3.6660e-04,  ..., -1.6240e-07,
#           -1.5027e-03, -3.6219e-04],
#          [ 3.2638e-04,  2.5455e-04,  2.9532e-04,  ...,  5.0802e-07,
#            6.3871e-05,  2.3081e-04],
#          [-2.7526e-03, -3.1078e-03, -3.0068e-03,  ..., -1.4906e-05,
#            1.7555e-04, -3.4211e-03]]], dtype=torch.float64)
# Convergence Delta: tensor([-6.7252e+03,  1.4710e+04,  7.5325e+03,  1.8317e+04, -7.7966e+03,
#         -4.6432e+04,  2.8629e+03,  2.2766e+04, -1.6088e+02, -6.4267e+04,
#          3.1345e+02,  3.3626e+03, -2.4436e+02, -1.4284e+02, -1.1625e+04,
#          7.7070e+04,  2.5961e+02, -7.1101e+02, -1.0721e+03,  6.8045e+01,
#         -4.7513e+03,  7.2003e+03, -2.2217e+04,  4.2973e+02, -8.1113e+03,
#          2.1409e+01,  6.4057e+01,  1.6359e+02, -4.2376e+04, -5.7926e+01,
#         -3.1442e+04,  1.3079e+13,  1.7052e+11, -1.2687e+06,  1.8020e+08,
#          8.9053e+04,  7.3035e+09, -1.2992e+14,  1.0107e-01,  3.2921e+02,
#         -4.8449e+04,  1.2051e+03, -4.5143e+04, -5.7075e-01,  3.0432e+01,
#          2.1244e+01, -3.3251e+02,  2.0346e+02,  2.1864e+02,  9.8960e+01,
#          4.9817e+00, -3.3775e+01, -2.6840e+00, -3.2256e+01, -7.7038e+00,
#         -6.4294e+01,  1.8446e+01,  1.3505e+01,  3.2738e+01,  3.8601e+01,
#          7.4887e+03, -1.0623e+03,  1.9500e+02, -1.5172e+04,  1.9629e+02,
#         -6.0491e+02,  2.7704e+02, -1.5058e+03, -1.4788e+04, -3.0588e+04,
#         -1.7520e+04, -4.6427e+02, -2.1065e+04,  4.8157e+05,  3.2896e+01,
#          2.1118e+02,  1.0758e+05,  1.2011e+07, -4.5684e+05, -9.3411e+03,
#          9.2927e+04, -4.0693e+06, -1.8501e+04,  1.0033e+05,  4.7951e+05,
#          6.6181e+04,  6.9795e+06,  7.5775e+03,  8.6573e+04, -5.6939e+03,
#          3.0415e+05,  4.1178e+05,  2.5269e+06, -5.2860e+06, -2.0443e+08,
#          2.3272e+06,  8.5292e+06, -1.4225e+05,  6.0378e+05, -1.1293e+07,
#         -5.8403e+07, -2.0387e+04, -7.8811e+07,  3.3617e+07, -9.7193e+06,
#          7.4335e+07, -2.9315e+10, -6.4988e+09,  4.8854e+08, -9.0390e+05,
#          1.1752e+08, -1.7794e+06, -8.0375e+09,  6.5704e+04,  1.2865e+00,
#          1.2752e+02,  1.0836e+01, -3.2853e+00,  3.9821e+00, -3.8059e+00,
#          4.4242e+00,  5.9253e+00, -9.4429e+00,  1.5201e-01, -8.2781e-01,
#          8.7507e-01, -5.6803e-01,  1.2871e+01,  1.1322e+01,  1.5029e+01,
#         -2.2840e+01,  1.3405e+01,  2.0665e+01, -4.3476e+01,  1.2412e+03,
#         -1.5895e+01, -7.9354e+02,  5.3890e+00,  1.5812e+01, -1.7965e+01,
#         -2.0310e+00,  1.5908e+01,  1.4839e+01, -8.9099e+00,  3.5985e+00,
#          5.0645e+00, -4.4693e+00, -1.4281e+01,  1.4660e+01,  1.4844e+01,
#         -3.6542e+01, -5.7560e+01, -1.8547e+00,  6.5441e-01, -5.7999e+01,
#         -9.2824e+00,  1.1558e+01, -4.3259e-01,  3.1062e+01,  2.0933e-01,
#         -3.2423e+01, -5.0363e+01, -9.6229e+01, -3.2808e+02,  9.7528e+01,
#          6.3641e+01,  5.0907e+03,  7.7464e+00, -4.0837e+01,  1.0003e+02,
#          1.6146e+04,  1.5187e+03, -1.9666e+03, -9.3412e+02, -5.8091e+03,
#          8.5941e+02, -3.5210e+03, -4.9849e+02, -1.4325e+03,  1.1860e+03,
#         -3.3689e+02, -2.0902e+02,  3.5254e+02, -8.3578e+01,  7.4671e+02,
#         -6.7407e+02,  1.6048e+04, -1.4162e+06,  7.9270e+08,  4.3837e+03,
#         -1.9268e+03, -4.8344e+04,  4.8304e+04,  1.6500e+03,  2.5518e+10,
#         -2.9862e+09, -2.5835e+04, -8.0399e+05,  3.1187e+04,  1.3883e+09,
#          1.6711e+11, -1.2612e+03,  3.0935e+04, -2.6183e+05, -3.4443e+03,
#          7.7780e+05, -3.3750e+03, -5.9422e+02, -2.0532e+03,  1.4586e+02,
#         -9.9870e+03,  6.0679e+02,  7.2641e+01, -2.9281e+08,  1.3458e+06,
#          3.0762e+09,  1.9585e+03,  2.1457e+02, -2.1517e+06, -1.0131e+01,
#         -4.1638e+00, -1.2376e+01, -2.8906e+02, -5.3122e+01,  5.7620e+00,
#          3.5441e+00, -4.1593e+01, -8.9378e+00,  3.8523e-01, -2.7387e+00,
#          5.9981e+00,  2.3888e+00,  4.4442e+00, -1.1697e+01,  6.1752e+00,
#         -1.1806e+00,  2.3478e+00, -7.2269e+00, -3.2481e+02, -4.0592e+01,
#         -1.4215e+02,  1.0373e+01,  7.4798e+00, -6.2513e+00,  1.6431e+01,
#         -7.4330e+00,  9.5320e+01, -8.2927e+03,  4.5003e+06,  1.4575e+08,
#          2.8333e+05, -1.5154e+10,  7.0137e+00, -4.1464e+00,  1.3924e+01,
#         -1.6175e-01,  8.3498e+00,  3.2854e+00,  8.9048e+00,  4.4992e+00,
#          3.7931e+00,  3.0443e+00,  3.5654e+00,  2.5775e+00, -1.4426e+02,
#          1.1103e+01,  5.7788e+00,  2.1245e+02,  2.5554e-01,  5.9188e-01,
#          3.1093e+00,  4.4274e+03,  3.1649e+00, -3.1376e+03,  1.1842e+03,
#          2.4857e-01,  4.1575e+00,  8.0924e+00, -5.3924e+00, -1.3561e+01,
#          2.3577e+01,  1.1786e+01,  1.1171e+01,  2.5616e+01, -1.1699e+01,
#          4.4953e+00, -6.6932e+00,  7.1976e+00, -8.6189e+00,  3.9629e+00,
#          1.6343e+00,  1.1301e+01, -7.9591e+00,  9.9646e+00,  1.1146e+02,
#         -1.1018e+01, -2.3915e+01,  3.8868e+02,  1.5234e+01,  5.1965e+00,
#          4.6428e+00, -3.7630e+02,  1.5492e+01,  3.8855e+01, -1.5411e+01,
#          2.0686e+01, -1.8517e+01,  2.9947e+00,  1.1878e+01,  2.1066e+01,
#          1.0179e+01, -1.0654e+01,  1.2021e+01,  1.8759e+01,  4.3824e+00,
#         -5.8481e+01,  1.0868e+01,  1.7904e+01,  1.6847e+01,  1.8344e+01,
#         -5.4776e+00, -1.3881e+01,  9.8895e+00,  1.0618e+02, -1.1910e+00,
#          1.1286e+01, -5.3821e+00,  1.2606e+01,  1.4054e+01,  9.9727e+00,
#         -6.8611e+00,  1.5199e+00, -2.2197e+01,  4.2444e+00, -1.2197e+01,
#          3.0204e+01,  4.9610e+01, -4.0099e+01, -7.3191e+00, -2.0567e-02,
#         -5.4796e-01, -2.7571e+01,  8.7851e+00,  1.0510e+01,  1.2566e+01,
#         -5.6936e+00,  5.9373e+02, -8.0179e-01,  2.0168e+01,  2.5478e+01,
#         -2.0407e+01,  1.1260e+01, -6.5497e-01, -1.7463e+00, -1.9485e+01,
#          7.7676e+01, -3.0466e+03,  3.4858e+01,  8.5283e+01, -5.9335e+01,
#          5.0433e+01,  6.7628e+02,  2.5118e+02,  6.9166e+03, -1.6207e+04,
#          1.1238e+03, -1.5944e+05, -6.6639e+04, -8.4488e+03,  1.3812e+04,
#          1.9756e+04, -1.2079e+05,  5.6230e+04, -7.8106e+07,  5.8113e+03,
#          6.4805e+06, -1.5542e+08,  4.7664e+04,  1.5479e+05, -1.7805e+09,
#          1.6312e+06, -6.3255e+07,  2.0719e+05, -6.4131e+08, -2.2802e+05,
#         -2.9219e+05,  5.2125e+04,  7.4191e+03, -1.6396e+09, -9.9240e+08,
#         -1.7351e+06, -2.8505e+07,  4.6703e+07, -2.0650e+07, -3.2277e+09,
#          9.8183e+05,  5.3434e+03, -1.4334e+04, -2.1336e+05,  7.7231e+04,
#         -1.8979e+03, -1.2426e+05,  2.2817e+07, -2.9917e+03,  1.0117e+04,
#          5.9469e+05, -7.3715e+03, -6.1536e+04,  1.0709e+04,  2.3500e+01,
#         -1.5564e+02, -2.2740e+01, -4.2347e+03,  2.5162e+02,  5.1472e+02,
#          5.3253e+01,  5.4782e+00, -3.2182e+02, -3.2192e+02, -5.2706e+02,
#          7.9678e-01,  9.4135e-01, -2.5597e-01, -9.4178e+02, -1.0637e+04,
#         -3.7225e+01, -8.7957e+00,  9.2849e+00, -2.3524e+00, -3.5507e+00,
#         -5.0414e+00, -6.4854e-01, -5.3982e-01,  5.1643e+00, -1.7099e+00,
#          1.3096e+00, -4.8471e-01,  3.6341e+00, -2.7908e+00,  4.2960e-01,
#         -5.9761e-01, -5.1145e+00, -1.8108e+00,  9.4764e-01,  2.4601e+00,
#         -1.9941e+00,  1.5971e+00,  2.0881e+00, -2.7828e-01, -5.9905e-01,
#         -2.6548e+00, -1.0905e+00, -1.1613e+00,  2.2901e+00,  6.9953e-01,
#          1.1465e+01,  6.2306e-01, -5.2149e-01,  5.0256e-01, -1.2161e+00,
#         -7.6876e-01, -2.7372e-01, -9.1491e-01,  2.7211e-01, -1.3915e+00,
#          1.9826e-01, -4.7213e-01,  2.2398e-01, -6.3715e-02,  1.4864e-01,
#          3.5273e-01, -2.3963e-01, -2.9453e-01, -5.0592e-01, -9.8404e-01,
#         -1.9346e-01, -6.4974e-01, -3.6455e-01,  2.1857e-01,  7.7108e-01,
#          9.9589e-01, -2.4701e+00,  1.5453e-01,  6.2850e-01, -7.3480e-01,
#         -8.9891e-02, -5.4864e-01, -2.1129e+00, -7.9884e-02, -4.5375e-01,
#          4.3365e-01,  5.9498e-02,  9.0809e-01,  7.6993e-01,  8.4087e-02,
#         -1.0210e+00, -2.0553e+00,  1.0974e+00,  2.9345e-01, -3.7920e-02,
#          2.7188e-01, -5.3334e-01, -1.6997e-01,  4.5560e-01, -5.0558e-01,
#         -4.8577e-01, -5.5906e-01, -1.0329e+00, -1.5098e+00, -3.6161e-01,
#         -9.6897e-01, -4.3569e-01,  6.5890e-01,  1.5746e+00,  9.9010e-01,
#          6.2019e-01,  2.0024e+00,  1.1363e+00,  5.9368e+00,  2.4736e-01,
#          8.9751e-01,  4.4059e-01, -1.4654e+00,  1.2752e-01,  2.9361e+00,
#          7.7685e-01, -1.4341e+00, -9.1913e-01, -8.0599e-01, -1.3434e+00,
#         -1.2480e-01,  1.5463e-01, -1.1065e-01,  1.4724e+00,  2.3882e-01,
#         -2.7704e-01, -1.5273e+00, -1.3685e-02,  1.6005e-01,  7.0275e-01,
#         -9.5970e-02, -1.0073e+00, -1.3278e+00,  4.9372e-01, -4.0296e-01,
#          1.3809e+00,  1.0162e-01, -3.6051e-01,  1.9163e-01, -1.8990e-01,
#         -9.3385e-02,  1.0995e+00, -5.7591e-01,  7.2685e-01, -2.4567e+00,
#          1.3817e-01,  8.4798e-01,  2.6947e-01, -9.3940e-01,  1.0843e+00,
#         -3.8142e+00, -1.4642e+00,  7.4108e-01,  1.9426e-01,  6.8251e-01,
#          4.4118e-01, -1.4109e+00, -9.0193e-01, -2.2667e-01, -6.0584e-01,
#          1.1129e+00, -5.6164e-01, -3.4569e-01,  1.1033e-01, -3.1414e-01,
#          3.1060e-01, -3.7293e-01,  3.0478e-01, -3.4995e-02,  2.0553e-01,
#         -1.5119e+00, -1.4254e+00, -4.3826e-01,  6.1522e-01,  2.0307e-01,
#         -5.7758e-01], dtype=torch.float64)

# %%
attributions.size()
# Out:
# torch.Size([586, 65, 633])

# %%
at_0 = np.mean(np.array(attributions.cpu()),axis=0)

# %%
at_0.shape
# Out:
# (65, 633)

# %%
# We choose the last time step

# %%
a = at_0[T-1]

# %%
df_score = pd.DataFrame(zip(labels,a), columns = ['feature', 'score'])
df_score['score'] = np.abs(df_score['score'])
df_score.head(5)
# Out:
#      feature     score
# 0       open  0.000374
# 1      close  0.000372
# 2  adj close  0.000416
# 3     volume  0.000764
# 4       high  0.000073

# %%
# Then we create two dataframes: 1) Top 50 features without sentiment 2) Top 44 features + 6 sentiment features
df_no_sent = df_score[~df_score['feature'].isin(sentiments)]
df_no_sent = df_no_sent.sort_values('score').iloc[-50:,:]
selected_features_no_sentiments = list(df_no_sent['feature'])
selected_features_no_sentiments
# Out:
# ['volume_vpt_10',
#  'trend_ichimoku_conv_50',
#  'volatility_kch_50',
#  'momentum_wr_200',
#  'trend_adx_200',
#  'trend_aroon_up_200',
#  'trend_sma_fast_50',
#  'volatility_ui_200',
#  'momentum_stoch_rsi_200',
#  'volatility_ui_50',
#  'trend_macd_diff_100',
#  'volatility_dcl_100',
#  'volatility_dch_200',
#  'volatility_atr_50',
#  'others_cr_200',
#  'volatility_bbp_20',
#  'trend_dpo_100',
#  'trend_kst_100',
#  'volume_vpt_100',
#  'volume_vwap_50',
#  'trend_ichimoku_base_100',
#  'momentum_roc_200',
#  'trend_visual_ichimoku_a_100',
#  'volatility_bbp_200',
#  'momentum_kama_200',
#  'volatility_kcl_50',
#  'trend_psar_up_indicator_100',
#  'volatility_bbh_50',
#  'volatility_bbl_200',
#  'trend_macd_signal_200',
#  'trend_sma_fast_200',
#  'trend_adx_neg_200',
#  'trend_visual_ichimoku_b_200',
#  'others_dr_100',
#  'volume_vpt_200',
#  'volatility_bbl_20',
#  'volatility_kcl_200',
#  'volatility_bbli_20',
#  'volatility_dch_100',
#  'volatility_kchi_50',
#  'trend_ichimoku_base_200',
#  'trend_kst_sig_100',
#  'volatility_kcp_50',
#  'trend_vortex_ind_pos_50',
#  'trend_vortex_ind_diff_50',
#  'momentum_ao',
#  'trend_macd_5',
#  'volatility_bbl',
#  'volatility_bbw',
#  'volatility_dcw']

# %%
selected_features_with_sentiments = selected_features_no_sentiments[:44] + sentiments

# %%
len(selected_features_with_sentiments)
# Out:
# 50

# %% [markdown]
# # LSTM for selected features only without and with sentiments (_sf1/_sf2)

# %%
# With no sentiments
input_data_sf1 = DF[selected_features_no_sentiments].values
targets_sf1 = DF['ln_target'].values

# %%
# With sentiments
input_data_sf2 = DF[selected_features_with_sentiments].values
targets_sf2 = DF['ln_target'].values

# %%
# We can use same features for other modells
#DF[selected_features_no_sentiments].to_csv('../datasets/exported/LSTM_TV18BRDCST_no_sentiemnts.csv')
#DF[selected_features_with_sentiments].to_csv('../datasets/exported/LSTM_TV18BRDCST_with_sentiemnts.csv')

# %%
# Preparing data for the neural network
T_sf1 = 10 # the number of days in  (a week, month, one quarter) to look at to make a prediction for the next day (Time window - look back)
D_sf1 = input_data_sf1.shape[1] # number of features
N_sf1 = len(input_data_sf1) - T_sf1 # Number of samples with Time window length

# %%
# Preparing data for the neural network
T_sf2 = 10 # the number of days in (a week, month, one quarter) to look at to make a prediction for the next day (Time window - look back)
D_sf2 = input_data_sf2.shape[1] # number of features
N_sf2 = len(input_data_sf2) - T_sf2 # Number of samples with Time window length

# %%
D_sf1
# Out:
# 50

# %%
N_sf1
# Out:
# 4009

# %%
# split and normalize the inputs for selected features for model with no sentiments
Ntrain_sf1 = len(input_data_sf1) * 4 // 5
scaler_sf1 = StandardScaler()
scaler_sf1.fit(input_data_sf1[:Ntrain_sf1 + T_sf1 - 1])
input_data_sf1[:Ntrain_sf1 + T_sf1 - 1] = scaler_sf1.transform(input_data_sf1[:Ntrain_sf1 + T_sf1 - 1])
input_data_sf1[Ntrain_sf1 + T_sf1 - 1:] = scaler_sf1.transform(input_data_sf1[Ntrain_sf1 + T_sf1 - 1:])

# %%
# split and normalize the inputs for selected features for model with sentiments
Ntrain_sf2 = len(input_data_sf2) * 4 // 5
scaler_sf2 = StandardScaler()
scaler_sf2.fit(input_data_sf2[:Ntrain_sf2 + T_sf2 - 1])
input_data_sf2[:Ntrain_sf2 + T_sf2 - 1] = scaler_sf2.transform(input_data_sf2[:Ntrain_sf2 + T_sf2 - 1])
input_data_sf2[Ntrain_sf2 + T_sf2 - 1:] = scaler_sf2.transform(input_data_sf2[Ntrain_sf2 + T_sf2 - 1:])

# %%
Ntrain_sf1 + T_sf1 - 1
# Out:
# 3224

# %%
# Setup X_train_sf and Y_train_sf for model with no sentiments
X_train_sf1 = np.zeros((Ntrain_sf1, T_sf1, D_sf1))
Y_train_sf1 = np.zeros((Ntrain_sf1, 1))
for t_sf1 in range(Ntrain_sf1):
    X_train_sf1[t_sf1, :, :] = input_data_sf1[t_sf1:t_sf1+T_sf1]
    Y_train_sf1[t_sf1] = targets_sf1[t_sf1+T_sf1]

# %%
# Setup X_train_sf and Y_train_sf for model with sentiments
X_train_sf2 = np.zeros((Ntrain_sf2, T_sf2, D_sf2))
Y_train_sf2 = np.zeros((Ntrain_sf2, 1))
for t_sf2 in range(Ntrain_sf2):
    X_train_sf2[t_sf2, :, :] = input_data_sf2[t_sf2:t_sf2+T_sf2]
    Y_train_sf2[t_sf2] = targets_sf2[t_sf2+T_sf2]

# %%
# Setup X_test_sf and Y_test_sf for model with no sentiments
X_test_sf1 = np.zeros((N_sf1 - Ntrain_sf1, T_sf1, D_sf1))
Y_test_sf1 = np.zeros((N_sf1 - Ntrain_sf1, 1))
for z_sf1 in range(N_sf1 - Ntrain_sf1):
    # z_sf1 counts from 0...(N_sf1 - Ntrain_sf1)
    # t_sf1 counts from Ntrain_sf1...N_sf1
    t_sf1 = z_sf1 + Ntrain_sf1
    X_test_sf1[z_sf1, :, :] = input_data_sf1[t_sf1:t_sf1+T_sf1]
    Y_test_sf1[z_sf1] = targets_sf1[t_sf1+T_sf1]

# %%
# Setup X_test_sf and Y_test_sf for model with sentiments
X_test_sf2 = np.zeros((N_sf2 - Ntrain_sf2, T_sf2, D_sf2))
Y_test_sf2 = np.zeros((N_sf2 - Ntrain_sf2, 1))
for z_sf2 in range(N_sf2 - Ntrain_sf2):
    # z_sf2 counts from 0...(N_sf2 - Ntrain_sf2)
    # t_sf2 counts from Ntrain_sf2...N_sf2
    t_sf2 = z_sf2 + Ntrain_sf2
    X_test_sf2[z_sf2, :, :] = input_data_sf2[t_sf2:t_sf2+T_sf2]
    Y_test_sf2[z_sf2] = targets_sf2[t_sf2+T_sf2]

# %%
### LSTM model for model with no sentiments (to be able to change parameters if required)
class RNN_sf1(nn.Module):
  def __init__(self, n_inputs, n_hidden, n_rnnlayers, n_outputs):
    super(RNN_sf1, self).__init__()
    self.D = n_inputs
    self.M = n_hidden
    self.K = n_outputs
    self.L = n_rnnlayers

    self.rnn = nn.LSTM(
        input_size=self.D,
        hidden_size=self.M,
        num_layers=self.L,
        batch_first=True)
    self.fc = nn.Linear(self.M, self.K)
  
  def forward(self, X):
    # initial hidden and cell states
    h0 = torch.zeros(self.L, X.size(0), self.M).to(device)
    c0 = torch.zeros(self.L, X.size(0), self.M).to(device)

    # get LSTM unit output
    out, _ = self.rnn(X, (h0, c0))

    # we only want h(T) at the final time step (-1)
    out = self.fc(out[:, -1, :])
    return out

# %%
model_sf1 = RNN_sf1(input_data_sf1.shape[1], 45, 1, 1) # the number of hidden features 45 (less than 50), 1 hidden layer
device = torch.device('cpu')
model_sf1.to(device)
# Out:
# RNN_sf1(
#   (rnn): LSTM(50, 45, batch_first=True)
#   (fc): Linear(in_features=45, out_features=1, bias=True)
# )

# %%
### LSTM model for model with sentiments (to be able to change parameters if required)
class RNN_sf2(nn.Module):
  def __init__(self, n_inputs, n_hidden, n_rnnlayers, n_outputs):
    super(RNN_sf2, self).__init__()
    self.D = n_inputs
    self.M = n_hidden
    self.K = n_outputs
    self.L = n_rnnlayers

    self.rnn = nn.LSTM(
        input_size=self.D,
        hidden_size=self.M,
        num_layers=self.L,
        batch_first=True)
    self.fc = nn.Linear(self.M, self.K)
  
  def forward(self, X):
    # initial hidden and cell states
    h0 = torch.zeros(self.L, X.size(0), self.M).to(device)
    c0 = torch.zeros(self.L, X.size(0), self.M).to(device)

    # get LSTM unit output
    out, _ = self.rnn(X, (h0, c0))

    # we only want h(T) at the final time step (-1)
    out = self.fc(out[:, -1, :])
    return out

# %%
model_sf2 = RNN_sf2(input_data_sf2.shape[1], 45, 1, 1)
device = torch.device('cpu')
model_sf2.to(device)
# Out:
# RNN_sf2(
#   (rnn): LSTM(50, 45, batch_first=True)
#   (fc): Linear(in_features=45, out_features=1, bias=True)
# )

# %%
# Loss and optimizer for model with no sentiments (to be able to change parameters if required)
# criterion = nn.BCEWithLogitsLoss() # if classification task
criterion_sf1 = nn.L1Loss()
optimizer_sf1 = torch.optim.Adam(model_sf1.parameters(), lr=0.1)

# %%
# Loss and optimizer for model with sentiments (to be able to change parameters if required)
# criterion = nn.BCEWithLogitsLoss() # if classification task
criterion_sf2 = nn.L1Loss()
optimizer_sf2 = torch.optim.Adam(model_sf2.parameters(), lr=0.1)

# %%
# Make inputs and targets to Torch format (tenzors)
X_train_sf1 = torch.from_numpy(X_train_sf1.astype(np.float32))
y_train_sf1 = torch.from_numpy(Y_train_sf1.astype(np.float32))
X_test_sf1 = torch.from_numpy(X_test_sf1.astype(np.float32))
y_test_sf1 = torch.from_numpy(Y_test_sf1.astype(np.float32))

# %%
# Make inputs and targets to Torch format (tenzors)
X_train_sf2 = torch.from_numpy(X_train_sf2.astype(np.float32))
y_train_sf2 = torch.from_numpy(Y_train_sf2.astype(np.float32))
X_test_sf2 = torch.from_numpy(X_test_sf2.astype(np.float32))
y_test_sf2 = torch.from_numpy(Y_test_sf2.astype(np.float32))

# %%
# move data to CPU (in case of Nvidia GPU card --> cuda)
X_train_sf1, y_train_sf1 = X_train_sf1.to(device), y_train_sf1.to(device)
X_test_sf1, y_test_sf1 = X_test_sf1.to(device), y_test_sf1.to(device)

# %%
# move data to CPU (in case of Nvidia GPU card --> cuda)
X_train_sf2, y_train_sf2 = X_train_sf2.to(device), y_train_sf2.to(device)
X_test_sf2, y_test_sf2 = X_test_sf2.to(device), y_test_sf2.to(device)

# %%
# Training
def full_gd_sf(model,
           criterion,
           optimizer,
           X_train,
           y_train,
           X_test,
           y_test,
           epochs = 200):
    # Losses to store
    train_losses = np.zeros(epochs)
    test_losses = np.zeros(epochs)
    
    for it in range(epochs):
        #zero the parameter gradients
        optimizer.zero_grad()
        
        # Forward pass
        outputs = model(X_train)
        loss = criterion(outputs, y_train)
        
        #Backward and optimize
        loss.backward()
        optimizer.step()
        
        #Save losses
        train_losses[it] = loss.item()
        
        #Test loss
        test_outputs = model(X_test)
        test_loss = criterion(test_outputs, y_test)
        test_losses[it] = test_loss.item()
        
        if (it+1)%5 == 0:
            print(f'Epoch {it+1}/{epochs}, Train Loss: {loss.item():.4f}, test Loss: {test_loss.item():.4f}')
            #checkpoint(model, f"LSTM/Epoch_TV18BRDCST_50-{it+1}.pth") # uncomment if you want to update the weights
    return train_losses, test_losses

# %%
train_losses_sf1, test_losses_sf1 = full_gd_sf(model_sf1,
                                    criterion_sf1,
                                    optimizer_sf1,
                                    X_train_sf1,
                                    y_train_sf1,
                                    X_test_sf1,
                                    y_test_sf1,
                                    epochs=150)
# Out:
# Epoch 5/150, Train Loss: 0.4627, test Loss: 0.7429
# Epoch 10/150, Train Loss: 0.4924, test Loss: 0.8472
# Epoch 15/150, Train Loss: 0.6065, test Loss: 0.7702
# Epoch 20/150, Train Loss: 0.2542, test Loss: 0.0456
# Epoch 25/150, Train Loss: 0.1921, test Loss: 0.1023
# Epoch 30/150, Train Loss: 0.0953, test Loss: 0.4069
# Epoch 35/150, Train Loss: 0.1949, test Loss: 0.0871
# Epoch 40/150, Train Loss: 0.1513, test Loss: 0.3394
# Epoch 45/150, Train Loss: 0.0794, test Loss: 0.2655
# Epoch 50/150, Train Loss: 0.1526, test Loss: 0.1142
# Epoch 55/150, Train Loss: 0.1148, test Loss: 0.2464
# Epoch 60/150, Train Loss: 0.0993, test Loss: 0.1656
# Epoch 65/150, Train Loss: 0.1927, test Loss: 0.1289
# Epoch 70/150, Train Loss: 0.1417, test Loss: 0.2238
# Epoch 75/150, Train Loss: 0.0812, test Loss: 0.1841
# Epoch 80/150, Train Loss: 0.1294, test Loss: 0.0679
# Epoch 85/150, Train Loss: 0.0859, test Loss: 0.1663
# Epoch 90/150, Train Loss: 0.1203, test Loss: 0.1214
# Epoch 95/150, Train Loss: 0.0571, test Loss: 0.1687
# Epoch 100/150, Train Loss: 0.0893, test Loss: 0.0493
# Epoch 105/150, Train Loss: 0.1645, test Loss: 0.2960
# Epoch 110/150, Train Loss: 0.1291, test Loss: 0.1316
# Epoch 115/150, Train Loss: 0.1820, test Loss: 0.1823
# Epoch 120/150, Train Loss: 0.1499, test Loss: 0.3077
# Epoch 125/150, Train Loss: 0.0641, test Loss: 0.2314
# Epoch 130/150, Train Loss: 0.1265, test Loss: 0.0712
# Epoch 135/150, Train Loss: 0.0731, test Loss: 0.1856
# Epoch 140/150, Train Loss: 0.1147, test Loss: 0.1293
# Epoch 145/150, Train Loss: 0.2084, test Loss: 0.1268
# Epoch 150/150, Train Loss: 0.1597, test Loss: 0.2357

# %%
# Plot the train loss and test loss per iteration for selected features (no sentiments)
plt.plot(train_losses_sf1, label='train loss_sf_no_sent')
plt.plot(test_losses_sf1, label='test loss_sf_no_sent')
plt.legend()
plt.show()

# %%
# checkpoint = torch.load(filename) - in case if early stop happens at intermediate eposh
# model.load_state_dict(checkpoint['model'])

# %%
train_losses_sf2, test_losses_sf2 = full_gd_sf(model_sf2,
                                    criterion_sf2,
                                    optimizer_sf2,
                                    X_train_sf2,
                                    y_train_sf2,
                                    X_test_sf2,
                                    y_test_sf2,
                                    epochs=150)
# Out:
# Epoch 5/150, Train Loss: 0.6780, test Loss: 0.1899
# Epoch 10/150, Train Loss: 0.3654, test Loss: 0.0372
# Epoch 15/150, Train Loss: 0.1847, test Loss: 0.0273
# Epoch 20/150, Train Loss: 0.1689, test Loss: 0.0661
# Epoch 25/150, Train Loss: 0.2138, test Loss: 0.0447
# Epoch 30/150, Train Loss: 0.1853, test Loss: 0.0416
# Epoch 35/150, Train Loss: 0.0705, test Loss: 0.1139
# Epoch 40/150, Train Loss: 0.1320, test Loss: 0.0524
# Epoch 45/150, Train Loss: 0.1876, test Loss: 0.0283
# Epoch 50/150, Train Loss: 0.1678, test Loss: 0.0834
# Epoch 55/150, Train Loss: 0.0609, test Loss: 0.0288
# Epoch 60/150, Train Loss: 0.0985, test Loss: 0.0266
# Epoch 65/150, Train Loss: 0.1355, test Loss: 0.0242
# Epoch 70/150, Train Loss: 0.1188, test Loss: 0.1086
# Epoch 75/150, Train Loss: 0.0478, test Loss: 0.1473
# Epoch 80/150, Train Loss: 0.1908, test Loss: 0.1619
# Epoch 85/150, Train Loss: 0.1826, test Loss: 0.1480
# Epoch 90/150, Train Loss: 0.1246, test Loss: 0.2132
# Epoch 95/150, Train Loss: 0.1782, test Loss: 0.3310
# Epoch 100/150, Train Loss: 0.1796, test Loss: 0.0674
# Epoch 105/150, Train Loss: 0.1507, test Loss: 0.0712
# Epoch 110/150, Train Loss: 0.1234, test Loss: 0.2302
# Epoch 115/150, Train Loss: 0.2052, test Loss: 0.0285
# Epoch 120/150, Train Loss: 0.0857, test Loss: 0.0473
# Epoch 125/150, Train Loss: 0.0562, test Loss: 0.0681
# Epoch 130/150, Train Loss: 0.0850, test Loss: 0.1216
# Epoch 135/150, Train Loss: 0.0588, test Loss: 0.0335
# Epoch 140/150, Train Loss: 0.0440, test Loss: 0.0617
# Epoch 145/150, Train Loss: 0.0271, test Loss: 0.0330
# Epoch 150/150, Train Loss: 0.0552, test Loss: 0.0980

# %%
# Plot the train loss and test loss per iteration for selected features (with sentiments)
plt.plot(train_losses_sf2, label='train loss_sf with sentiment')
plt.plot(test_losses_sf2, label='test loss_sf_with sentiment')
plt.legend()
plt.show()

# %%
# retrieving 100th iteration
model_sf1 = RNN_sf1(input_data_sf1.shape[1], 45, 1, 1)
model_sf1.load_state_dict(torch.load('LSTM/Epoch_TV18BRDCST_no_sent__50-100.pth'))
model_sf1.eval()
# Out:
# RNN_sf1(
#   (rnn): LSTM(50, 45, batch_first=True)
#   (fc): Linear(in_features=45, out_features=1, bias=True)
# )

# %%
# retrieving 145th iteration
model_sf2 = RNN_sf2(input_data_sf1.shape[1], 45, 1, 1)
model_sf2.load_state_dict(torch.load('LSTM/Epoch_TV18BRDCST_w_sent_50-145.pth'))
model_sf2.eval()
# Out:
# RNN_sf2(
#   (rnn): LSTM(50, 45, batch_first=True)
#   (fc): Linear(in_features=45, out_features=1, bias=True)
# )

# %%
X_on_device_sf1 = X_test_sf1.to(device)
X_on_device_sf2 = X_test_sf2.to(device)

# %%
X_on_device_sf1.shape
# Out:
# torch.Size([794, 10, 50])

# %%
# One-day forecast 
test_target_sf1 = Y_test_sf1
test_predictions_sf1 = []
# index of first validation input
i_sf1 = 0

X_on_device_sf1 = X_test_sf1.to(device)
while len(test_predictions_sf1) < len(test_target_sf1):
    input__sf1 = X_on_device_sf1[i_sf1].reshape(-1, T_sf1, input_data_sf1.shape[1])
    p_sf1 = model_sf1(input__sf1)[0,0].item() 
    i_sf1 += 1
    test_predictions_sf1.append(p_sf1)

# %%
plt.plot(np.exp(test_target_sf1), label = 'forecast target sf no sentiments')
plt.plot(np.exp(test_predictions_sf1), label = 'forecast prediction sf no sentiments')
plt.legend()

# %%
# We see that time window impacts our predictions

# %%
# One-step forecast 
test_target_sf2 = Y_test_sf2
test_predictions_sf2 = []
# index of first validation input
i_sf2 = 0

X_on_device_sf2 = X_test_sf2.to(device)
while len(test_predictions_sf2) < len(test_target_sf2):
    input__sf2 = X_on_device_sf2[i_sf2].reshape(-1, T_sf2, input_data_sf2.shape[1])
    p_sf2 = model_sf2(input__sf2)[0,0].item() 
    i_sf2 += 1
    test_predictions_sf2.append(p_sf2)

# %%
plt.plot(np.exp(test_target_sf2), label = 'forecast target sf with sentiments')
plt.plot(np.exp(test_predictions_sf2), label = 'forecast prediction sf with sentiments')
plt.legend()

# %%
mean_absolute_percentage_error(np.exp(test_target_sf1), np.exp(test_predictions_sf1))
# Out:
# 0.04712377346610187

# %%
mean_absolute_percentage_error(np.exp(test_target_sf2), np.exp(test_predictions_sf2))
# Out:
# 0.03161751267981273

# %% [markdown]
# # Visualization of results

# %% [markdown]
# For visulaisation purpose, we use Altair library, which requires 'long-shape' dataframe. First we merge predicted values with original dataframe, then we transform it to Altair format.

# %%
pred_date = DF.iloc[-len(y_test_sf1):,0]

# %%
# converting back to target predictions
results_array = np.column_stack((pred_date,np.exp(test_predictions_sf1),np.exp(test_predictions_sf2)))

# %%
# Creating dataframe with results
df_result = pd.DataFrame({"date":results_array .T[0],
                   "LSTM (no sentiments)":results_array .T[1],
                   "LSTM (with sentiments)":results_array .T[2]})

# %%
columns = ['date','high','yesterday_close', 'ln_target']

# %%
# Merging results with the actual data
result = pd.merge(DF[columns], df_result, how="left", on=["date", "date"])

# %%
# Recalculating predicted High price from return
result['Predicted high LSTM (no sentiments)'] = result['yesterday_close']*result['LSTM (no sentiments)']
result['Predicted high LSTM (with sentiments)'] = result['yesterday_close']*result['LSTM (with sentiments)']
result['Actual High/Close_yesterday'] = np.exp(result['ln_target'])
result = result.drop('ln_target', axis=1)
result.rename(columns = {'high':'Actual High'}, inplace = True)

# %%
# Let's focus only on test interval
result = result.iloc[-len(y_test_sf1):,:]

# %%
result[['date', 'Actual High','Predicted high LSTM (no sentiments)',
        'Predicted high LSTM (with sentiments)']].to_csv('../datasets/processed_data/model_predictions/LSTM/TV18BRDCST_LSTM_predictions.csv', index = False)

# %%
# MAPE calculation for predicted "High" price
a = mean_absolute_percentage_error(result['Predicted high LSTM (no sentiments)'], result['Actual High'])
b = mean_absolute_percentage_error(result['Predicted high LSTM (with sentiments)'],result['Actual High'])
print(a,b)
# Out:
# 0.14168033291143642 0.11031967124858919

# %%
# For Altair visualization we melt pandas dataframes into long shape format and then concat them
melted_df1 = pd.melt(result, id_vars =['date','yesterday_close'],
                     value_vars =['Actual High','Predicted high LSTM (no sentiments)','Predicted high LSTM (with sentiments)'],
                    var_name ='High method', value_name ='High prediction price')
melted_df2 = pd.melt(result, id_vars =['date','yesterday_close'], value_vars =['Actual High/Close_yesterday','LSTM (no sentiments)','LSTM (with sentiments)'],
                    var_name ='High/Close_yesterday method', value_name ='High/Close_yesterday')
melted_df = pd.concat([melted_df1,melted_df2[['High/Close_yesterday method','High/Close_yesterday']]], axis = 1)

# %%
melted_df.head(5)
# Out:
#          date  yesterday_close  High method High prediction price  \
# 0  2022-04-28        61.849998  Actual High                  81.0
# 1  2022-04-28        61.849998  Actual High                  81.0
# 2  2022-04-28        61.849998  Actual High                  81.0
# 3  2022-04-28        61.849998  Actual High                  81.0
# 4  2022-04-28        61.849998  Actual High                  81.0
#
#    High/Close_yesterday method High/Close_yesterday
# 0  Actual High/Close_yesterday              1.30962
# 1  Actual High/Close_yesterday              1.30962
# 2  Actual High/Close_yesterday              1.30962
# 3  Actual High/Close_yesterday              1.30962
# 4  Actual High/Close_yesterday              1.30962

# %%
# use the 538 theme
alt.themes.enable('fivethirtyeight')
alt.data_transformers.enable('default', max_rows=None)
# Out:
# DataTransformerRegistry.enable('default')

# %%
high_price = alt.Chart(melted_df, title="TV18BRDCST LSTM 'high' stock price prediction results").mark_line().encode(
    x=alt.X('date:T', title="Year"),
    y = alt.Y('High prediction price:Q', title="Price"),
    color = alt.Color('High method:N',legend=alt.Legend(orient='left',direction = 'vertical',labelLimit = 400))
    ).properties(height = 250, width = 800
    ).configure_legend(
    offset=-330,
    symbolDirection='vertical',
        titleFontSize=16,
        labelFontSize=14
    )

high_price.interactive()
# Out:
# alt.Chart(...)

# %%
high_close_yesterday_ratio = alt.Chart(melted_df, title="TV18BRDCST LSTM 'High / Close_yesterday' stock price prediction results").mark_line().encode(
    x=alt.X('date:T', title="Year"),
    y = alt.Y('High/Close_yesterday:Q', title="High / Close_yesterday"),
    color = alt.Color('High/Close_yesterday method:N',
                      legend=alt.Legend(orient='right',direction = 'vertical',labelLimit = 400))
    ).properties(height = 250, width = 800
    ).configure_legend(
    offset=-260,
    symbolDirection='vertical',
        titleFontSize=16,
        labelFontSize=14
    )

high_close_yesterday_ratio.interactive()
# Out:
# alt.Chart(...)

# %%
# Both models show moderate performance for High/Close_yesterday prediction.
